# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("D:/Vcodez Datasets/insurance.csv")

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.style.use('dark_background')
plt.plot(data['age'],data['bmi'],marker='v')
plt.show()

# %%
plt.bar(data['age'],data['bmi'],color='blue')
plt.show()

# %%
X = data [['age','children','charges']]
y = data['bmi']

# %%
X.shape
# Out:
# (1338, 3)

# %%
y.shape
# Out:
# (1338,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=2)
X_train.shape
# Out:
# (936, 3)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_)
# Out:
# [ 2.26288081e-02 -1.55153699e-01  9.48578664e-05]

# %%
print(model.intercept_)
# Out:
# 28.66505953294869

# %%
predicted = model.predict(X_test)
print(predicted)
# Out:
# [29.41272298 30.98026096 30.55365718 29.08032644 30.03866051 30.08468963
#  30.24914421 29.28073084 31.44283616 29.92115266 31.13696846 29.12775621
#  31.10434603 29.17879664 32.09960212 30.91597378 29.68968918 29.56159101
#  30.92382201 29.28139472 31.07809225 29.23153058 32.69331276 31.53338294
#  32.4082808  30.93559269 29.53494066 30.08894328 29.460285   29.55475452
#  30.03696064 29.49614815 29.5240507  29.61358606 30.23571329 29.22715465
#  32.75216947 31.43938042 32.54217049 32.47414774 29.29585313 32.47817107
#  30.36452293 29.33073388 30.08095176 29.61136744 30.28207311 29.49543178
#  29.43829576 31.86658866 28.80809929 29.21289776 30.77859232 34.09854256
#  30.0313389  30.67121777 29.39498431 29.98437573 29.3672514  33.25795905
#  31.29671732 29.18460449 29.47856071 33.3649825  29.21277909 31.11056914
#  32.06777616 29.29597512 31.34463908 30.16640387 30.92504716 32.89472955
#  32.35892915 29.83800948 31.23138798 30.6004784  29.33189418 29.3213982
# ...

# %%
data1 = pd.DataFrame({'Actual': np.array(y_test).flatten(), 'Predicted' : np.array(predicted).flatten()})

# %%
data1.head(20)
# Out:
#     Actual  Predicted
# 0   23.845  29.412723
# 1   29.830  30.980261
# 2   27.455  30.553657
# 3   29.370  29.080326
# 4   21.850  30.038661
# 5   41.800  30.084690
# 6   26.790  30.249144
# 7   25.080  29.280731
# 8   25.080  31.442836
# 9   31.920  29.921153
# 10  27.170  31.136968
# 11  37.290  29.127756
# 12  22.220  31.104346
# 13  23.210  29.178797
# 14  35.910  32.099602
# 15  29.700  30.915974
# 16  25.460  29.689689
# 17  32.775  29.561591
# 18  25.300  30.923822
# 19  30.115  29.281395

# %%
import math
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test,predicted))
print('Mean Squared Error:', metrics.mean_squared_error(y_test,predicted))
print('Root Mean Squared Error:', math.sqrt(metrics.mean_squared_error(y_test,predicted)))
# Out:
# Mean Absolute Error: 4.789138367736362
# Mean Squared Error: 36.499993326324095
# Root Mean Squared Error: 6.041522434479913

# %%
graph = data1.head(20)

# %%
graph.plot(kind='line')
graph.plot(kind='bar')
graph.plot(kind='box')
# Out:
# <Axes: >

# %%
new_data = np.array([[530, 610,1400]])
predicted_price = model.predict(new_data)
print(f"Predicted Close Price: {predicted_price[0]}")
# Out:
# Predicted Close Price: -53.85262780838276
# C:\Users\AASMI NISHA M\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
